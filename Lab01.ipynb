# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehyun99/Computer_Vision/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

import matplotlib.pyplot as plt

# %%
img = cv2.imread("drive/MyDrive/PR201910807/images/lab01_rainbow.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=5962x3727>

# %%
img.shape
# Out:
# (3727, 5962, 3)

# %%
img = cv2.resize(img, (500,400))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400>

# %%
img
# Out:
# array([[[140,  56,  90],
#         [140,  56,  90],
#         [142,  56,  90],
#         ...,
#         [  0,   4, 206],
#         [  0,   3, 205],
#         [  0,   0, 204]],
#
#        [[140,  56,  90],
#         [140,  56,  90],
#         [142,  56,  90],
#         ...,
#         [  0,   4, 206],
#         [  0,   3, 205],
#         [  0,   1, 204]],
#
#        [[140,  56,  90],
#         [140,  56,  90],
#         [142,  56,  90],
#         ...,
#         [  0,   4, 206],
#         [  0,   3, 205],
#         [  0,   0, 204]],
#
#        ...,
#
#        [[ 43,  18,  28],
#         [ 43,  17,  29],
#         [ 44,  18,  28],
#         ...,
#         [  1,   1,  65],
#         [  1,   1,  65],
#         [  0,   0,  64]],
#
#        [[ 42,  17,  27],
#         [ 42,  17,  27],
#         [ 42,  17,  27],
#         ...,
#         [  1,   1,  64],
#         [  0,   1,  62],
#         [  1,   0,  62]],
#
#        [[ 44,  17,  27],
#         [ 42,  17,  27],
#         [ 42,  17,  27],
# ...

# %%
cv2_imshow(img[:100,:,:])
# Out:
# <PIL.Image.Image image mode=RGB size=500x100>

# %%
cv2_imshow(img[:,:,0])
# Out:
# <PIL.Image.Image image mode=L size=500x400>

# %%
cv2_imshow(img[:,:,1])
# Out:
# <PIL.Image.Image image mode=L size=500x400>

# %%
cv2_imshow(img[:,:,2])
# Out:
# <PIL.Image.Image image mode=L size=500x400>

# %%
bimg = img.copy()
bimg[:,:,1] = 0
bimg[:,:,2] = 0
cv2_imshow(bimg)
# Out:
# <PIL.Image.Image image mode=RGB size=500x400>

# %%
imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(imggray)
# Out:
# <PIL.Image.Image image mode=L size=500x400>

# %%
imggray.shape
# Out:
# (400, 500)

# %%
imggray.flatten().shape
# Out:
# (200000,)

# %%
plt.hist(imggray.flatten(), bins = 256)
# Out:
# (array([   6.,   31.,   87.,  162.,  248.,    0.,  264.,  313.,  396.,
#          422.,  397.,    0.,  433.,  487.,  516.,  462.,  493.,    0.,
#          565.,  563.,  545.,  555.,    0.,  659.,  612.,  622.,  669.,
#          706.,    0.,  743.,  758.,  873.,  884.,  889.,    0.,  931.,
#          968., 1003.,  971.,    0., 1075., 1017., 1098., 1125., 1179.,
#            0., 1742., 1574., 2143., 2298., 1890.,    0., 1964., 2448.,
#         1847., 1898.,    0., 2449., 2194., 1828., 2380., 2137.,    0.,
#         1738., 2128., 2071., 1673., 2058.,    0., 2347., 1554., 1751.,
#         1690.,    0.,  934., 1139., 1114.,  962., 1275.,    0.,  952.,
#         1112., 1093., 1081.,  928.,    0., 1126., 1052., 1089., 1103.,
#         1054.,    0., 1078.,  883.,  922., 1245.,    0.,  874., 1242.,
#          900.,  874., 1239.,    0., 1085.,  849., 1056., 1069.,  855.,
#            0., 1100.,  968., 1008., 1109.,    0.,  869., 1069., 1041.,
# ...

# %%
grayhist = cv2.calcHist([imggray], [0], None, [256], [0,256])
print(grayhist.shape)
# Out:
# (256, 1)

# %%
plt.plot(grayhist)

# %%
plt.hist(imggray.flatten(), bins = 256)
plt.plot(grayhist)
